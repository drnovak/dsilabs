# %%
import pandas as pd

# %%
standings_2015 = pd.read_csv('../data/seasons/2015standings.csv')

# %%
standings_2015.columns = [u'Rk', u'Tm', u'Lg', u'G', u'W', u'L', u'W-L%', u'R', u'RA', u'Rdiff',
       u'SOS', u'SRS', u'pythWL', u'Luck', u'Inter', u'Home', u'Road',
       u'ExInn', u'1Run', u'vRHP', u'vLHP', u'vs_over_500', u'vs_under_500']

# %%
standings_2015.head()
# Out:
#    Rk   Tm  Lg    G    W   L   W-L%    R   RA  Rdiff     ...       Luck  \
# 0   1  STL  NL  162  100  62  0.617  4.0  3.2    0.8     ...          4
# 1   2  PIT  NL  162   98  64  0.605  4.3  3.7    0.6     ...          5
# 2   3  CHC  NL  162   97  65  0.599  4.3  3.8    0.5     ...          7
# 3   4  KCR  AL  162   95  67  0.586  4.5  4.0    0.5     ...          5
# 4   5  TOR  AL  162   93  69  0.574  5.5  4.1    1.4     ...         -9
#
#     Inter   Home   Road  ExInn   1Run   vRHP   vLHP vs_over_500 vs_under_500
# 0   9-Nov  55-26  45-36  8-Aug  32-23  75-44  25-18       46-31        54-31
# 1    13-7  53-28  45-36  9-Dec  36-17  78-48  20-16       42-32        56-32
# 2  10-Oct  49-32  48-33   13-5  34-21  77-51  20-14       44-32        53-33
# 3    13-7  51-30  44-37  6-Oct  23-17  64-40  31-27       47-43        48-24
# 4   8-Dec  53-28  40-41  6-Aug  15-28  73-54  20-15       53-33        40-36
#
# [5 rows x 23 columns]

# %%
standings_2015 = standings_2015.drop(standings_2015.columns[[0, 2, 3, 10, 11, 12, 13, 14, 
                                                             17, 18, 19, 20]], axis=1)

# %%
standings_2015.head()
# Out:
#     Tm    W   L   W-L%    R   RA  Rdiff   Home   Road vs_over_500 vs_under_500
# 0  STL  100  62  0.617  4.0  3.2    0.8  55-26  45-36       46-31        54-31
# 1  PIT   98  64  0.605  4.3  3.7    0.6  53-28  45-36       42-32        56-32
# 2  CHC   97  65  0.599  4.3  3.8    0.5  49-32  48-33       44-32        53-33
# 3  KCR   95  67  0.586  4.5  4.0    0.5  51-30  44-37       47-43        48-24
# 4  TOR   93  69  0.574  5.5  4.1    1.4  53-28  40-41       53-33        40-36

# %%
standings_2015.dtypes
# Out:
# Tm               object
# W                 int64
# L                 int64
# W-L%            float64
# R               float64
# RA              float64
# Rdiff           float64
# Home             object
# Road             object
# vs_over_500      object
# vs_under_500     object
# dtype: object

# %%
standings_2015.rename(columns={'Tm': 'team', 'W': 'wins', 'L': 'losses', 'W-L%': 'win_loss', 'R': 'runs',
                               'RA': 'runs_allowed', 'Rdiff': 'run_differential','Home': 'home_success',
                               'Road': 'road_success'}, inplace=True)

# %%
standings_2015.head()
# Out:
#   team  wins  losses  win_loss  runs  runs_allowed  run_differential  \
# 0  STL   100      62     0.617   4.0           3.2               0.8
# 1  PIT    98      64     0.605   4.3           3.7               0.6
# 2  CHC    97      65     0.599   4.3           3.8               0.5
# 3  KCR    95      67     0.586   4.5           4.0               0.5
# 4  TOR    93      69     0.574   5.5           4.1               1.4
#
#   home_success road_success vs_over_500 vs_under_500
# 0        55-26        45-36       46-31        54-31
# 1        53-28        45-36       42-32        56-32
# 2        49-32        48-33       44-32        53-33
# 3        51-30        44-37       47-43        48-24
# 4        53-28        40-41       53-33        40-36

# %%
standings_2015['home_success'] = standings_2015.home_success.apply(lambda x: int(x.split('-')[0]) - int(x.split('-')[1]))
standings_2015['road_success'] = standings_2015.road_success.apply(lambda x: int(x.split('-')[0]) - int(x.split('-')[1]))
standings_2015['vs_over_500'] = standings_2015.vs_over_500.apply(lambda x: int(x.split('-')[0]) - int(x.split('-')[1]))
standings_2015['vs_under_500'] = standings_2015.vs_under_500.apply(lambda x: int(x.split('-')[0]) - int(x.split('-')[1]))

# %%
standings_2015.head()
# Out:
#   team  wins  losses  win_loss  runs  runs_allowed  run_differential  \
# 0  STL   100      62     0.617   4.0           3.2               0.8
# 1  PIT    98      64     0.605   4.3           3.7               0.6
# 2  CHC    97      65     0.599   4.3           3.8               0.5
# 3  KCR    95      67     0.586   4.5           4.0               0.5
# 4  TOR    93      69     0.574   5.5           4.1               1.4
#
#    home_success  road_success  vs_over_500  vs_under_500
# 0            29             9           15            23
# 1            25             9           10            24
# 2            17            15           12            20
# 3            21             7            4            24
# 4            25            -1           20             4

# %%
standings_2015.dtypes
# Out:
# team                 object
# wins                  int64
# losses                int64
# win_loss            float64
# runs                float64
# runs_allowed        float64
# run_differential    float64
# home_success          int64
# road_success          int64
# vs_over_500           int64
# vs_under_500          int64
# dtype: object

# %%
standings_2015.to_csv('standings_2015.csv', sep='\t', encoding='utf-8')
